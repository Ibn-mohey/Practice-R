# %%
setwd("E:/career/dataa/github/R-general-practice/Exploratory Data Analysis")
getwd()
# Out:
# [1] "E:/career/dataa/github/R-general-practice/Exploratory Data Analysis"

# %%
pollution <- read.csv("data/avgpm25.csv", colClasses = c("numeric", "character", 
                                                         "factor", "numeric", "numeric"))
head(pollution)
# Out:
#   pm25      fips  region longitude latitude
# 1  9.771185 01003 east   -87.74826 30.59278
# 2  9.993817 01027 east   -85.84286 33.26581
# 3 10.688618 01033 east   -87.72596 34.73148
# 4 11.337424 01049 east   -85.79892 34.45913
# 5 12.119764 01055 east   -86.03212 34.01860
# 6 10.827805 01069 east   -85.35039 31.18973

# %%
summary(pollution$pm25)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   3.383   8.549  10.047   9.836  11.356  18.441

# %%
boxplot(pollution$pm25, col = "blue")
# Out:
# plot without title

# %%
hist(pollution$pm25, col = "green")

hist(pollution$pm25, col = "green")
rug(pollution$pm25)
# Out:
# Plot with title "Histogram of pollution$pm25"

# %%
hist(pollution$pm25, col = "blue", breaks = 100)
rug(pollution$pm25)
# Out:
# Plot with title "Histogram of pollution$pm25"

# %%
boxplot(pollution$pm25, col = "blue")
abline(h = 12)
# Out:
# plot without title

# %%
barplot(table(pollution$region) , main = "test")
# Out:
# Plot with title "test"

# %%
#2 D plots
boxplot(pm25 ~ region, data = pollution, col="red")
# Out:
# plot without title

# %%
par(mfrow = c(2, 1) , mar = c(4,4,2,1))
hist(subset(pollution, region == "east")$pm25, col = "green")
hist(subset(pollution, region == "west")$pm25, col = "green")
# Out:
# Plot with title "Histogram of subset(pollution, region == "west")$pm25"

# %%
with(pollution, plot(latitude, pm25, col = region))
abline(h = 12, lwd = 2, lty = 2)
# Out:
# plot without title

# %%
par(mfrow = c(1,2), mar = c(5, 4, 2,1 ))
with(subset(pollution, region =="west"), plot(latitude, pm25 ))
with(subset(pollution, region =="east"), plot(latitude, pm25 ))
# Out:
# plot without title

# %%
library(datasets)
data(cars)
with(cars, plot(speed, dist))
# Out:
# plot without title

# %%
library(lattice)
state <- data.frame(state.x77, region = state.region)
xyplot(Life.Exp ~ Income | region, data = state, layout = c(4, 1))
# Out:
# plot without title

# %%
library(ggplot2)
data(mpg)
qplot(displ, hwy, data = mpg)
# Out:
# plot without title

# %%
# Out:
# Plot with title "Ozone and Wind in New York City"

# %%
with(airquality, plot(Wind, Ozone, main = "Ozone and Wind in New York City", 
    type = "n"))
with(subset(airquality, Month == 5), points(Wind, Ozone, col = "blue"))
with(subset(airquality, Month != 5), points(Wind, Ozone, col = "red"))
legend("topright", pch = 1, col = c("blue", "red"), legend = c("May", "Other Months"))
# Out:
# Plot with title "Ozone and Wind in New York City"

# %%
with(airquality, plot(Wind, Ozone, main = "Ozone and Wind in New York City", 
    pch = 20))
model <- lm(Ozone ~ Wind, airquality) #regression line
abline(model, lwd = 2)
# Out:
# Plot with title "Ozone and Wind in New York City"

# %%
par(mfrow = c(1, 2))
with(airquality, {
    plot(Wind, Ozone, main = "Ozone and Wind")
    plot(Solar.R, Ozone, main = "Ozone and Solar Radiation")
})
# Out:
# Plot with title "Ozone and Solar Radiation"

# %%
par(mfrow = c(1, 3))
with(airquality, {
    plot(Wind, Ozone, main = "Ozone and Wind")
    plot(Solar.R, Ozone, main = "Ozone and Solar Radiation")
    plot(Temp, Ozone, main = "Ozone and Temperature")
    mtext("Ozone and Weather in New York City", outer = TRUE)
})
# Out:
# Plot with title "Ozone and Temperature"
